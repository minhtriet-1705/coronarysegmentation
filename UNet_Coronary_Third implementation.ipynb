# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount = True)
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # 1. Visualize dataset
# Source: https://www.kaggle.com/code/nirmalgaud/artery-segment-classification-and-stenosis-detect

# %%
import os
import json
import numpy as np
import cv2
import matplotlib.pyplot as plt

import tensorflow as tf
from keras import layers, models
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose, BatchNormalization, Dropout, Lambda

# %%
def load_json(json_path): # mask images were stored as json files, so we need this function to read them
    with open(json_path, 'r') as f: # open in read mode
        data = json.load(f)
    return data

# %%
def create_mask(image_shape, segmentation):
    mask = np.zeros(image_shape, dtype=np.uint8) # create an empty mask filled with zeros that has the same shape as the image
    points = np.array(segmentation, dtype=np.int32).reshape(-1, 2) # convert segmentation points to numpy array and reshape
    cv2.fillPoly(mask, [points], color=255) # fill the polygon defined by the points with white color (255) - the vessel region
    return mask

# %%
def visualize_segmentation(image_path, annotations, categories, image_id, image_index):
    img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    img_color = cv2.cvtColor(img, cv2.COLOR_GRAY2RGB)
    img_annotations = [ann for ann in annotations if ann['image_id'] == image_id]
    mask = np.zeros_like(img, dtype=np.uint8)

    for ann in img_annotations:
        category_id = ann['category_id']
        category_name = next(cat['name'] for cat in categories if cat['id'] == category_id)
        segmentation = ann['segmentation']
        ann_mask = create_mask(img.shape, segmentation)
        mask = np.maximum(mask, ann_mask)
        img_color[ann_mask == 255] = [255, 0, 0]

    plt.figure(figsize=(10, 5))
    plt.subplot(1, 2, 1)
    plt.title(f"Original Image {image_index + 1}")
    plt.imshow(img, cmap='gray')
    plt.axis('off')

    plt.subplot(1, 2, 2)
    plt.title(f"Segmented Image {image_index + 1} (ID: {image_id})")
    plt.imshow(img_color)
    plt.axis('off')

    plt.show()
    return mask

# %%
def main():
    base_path = "/content/gdrive/MyDrive/EMMBIOME/SERBIA/Biomedical Imaging/Seminar Paper/ARCADE/syntax"
    train_images_path = os.path.join(base_path, "train", "images")
    train_json_path = os.path.join(base_path, "train", "annotations", "train.json")

    data = load_json(train_json_path)
    images = data['images']
    annotations = data['annotations']
    categories = data['categories']

    for idx, sample_image in enumerate(images[:3]):
        image_id = sample_image['id']
        image_file = sample_image['file_name']
        image_path = os.path.join(train_images_path, image_file)

        print(f"Processing image: {image_file}")
        visualize_segmentation(image_path, annotations, categories, image_id, idx)

if __name__ == "__main__":
    main()
# Out:
# Processing image: 922.png
# Processing image: 793.png
# Processing image: 782.png

# %% [markdown]
# # 2. Preprocessing images and preparing a dataset

# %%
IMG_HEIGHT = 256
IMG_WIDTH = 256
dataset = "/content/gdrive/MyDrive/EMMBIOME/SERBIA/Biomedical Imaging/Seminar Paper/ARCADE/syntax"
train_img_path = os.path.join(dataset, "train/images")
train_json_path = os.path.join(dataset, "train/annotations/train.json")

val_img_path = os.path.join(dataset, "val/images")
val_json_path = os.path.join(dataset, "val/annotations/val.json")

train_json = load_json(train_json_path)
val_json = load_json(val_json_path)

# %%
def preprocess_image(image_path):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE) # read the image in grayscale mode
    image = cv2.resize(image, (IMG_WIDTH, IMG_HEIGHT)) # resize the image to the dimensions 256x256
    image = cv2.GaussianBlur(image, (3, 3), 0) # apply Gaussian blur to reduce noise and improve contrast
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8)) # create a CLAHE object with a clip limit of 2.0 and a tile grid size of 8x8
    image= clahe.apply(image)
    image = image.astype(np.float32) / 255.0 # normalize pixel values to [0, 1]
    image = np.expand_dims(image, axis=-1) # add channel dimension for grayscale images (shape: (256, 256, 1)) for U-Net input
    return image

# %%
def preprocess_mask(image_shape, annotations, image_id):
    mask = np.zeros(image_shape, dtype=np.uint8) # create an empty mask filled with zeros 
    for ann in annotations:
        if ann['image_id'] == image_id:
            segmentation = ann['segmentation'] # get the segmentation points for the current image
            ann_mask = create_mask(image_shape, segmentation) # create a binary mask for the current annotation
            mask = np.maximum(mask, ann_mask) # combine masks from multiple annotations by taking the maximum value at each pixel 
    mask = cv2.resize(mask, (IMG_WIDTH, IMG_HEIGHT)) # resize the mask to match the dimensions 256 x 256
    mask = (mask > 0).astype(np.float32) # convert to binary mask (0 and 1) and float32 type for U-Net training
    mask = np.expand_dims(mask, axis=-1) # add channel dimension for U-Net input -> shape: (256, 256, 1)
    return mask

# %%
def create_dataset(images, annotations, images_path):
    X = []
    Y = []

    for img_info in images:
        image_id = img_info['id']
        image_file = img_info['file_name']
        image_path = os.path.join(images_path, image_file)

        image = preprocess_image(image_path)
        mask = preprocess_mask(
            image_shape=cv2.imread(image_path, cv2.IMREAD_GRAYSCALE).shape,
            annotations=annotations,
            image_id=image_id
        )

        X.append(image)
        Y.append(mask)

    return np.array(X), np.array(Y)

# %%
images = train_json['images']
annotations = train_json['annotations']
X_train, Y_train = create_dataset(
    images=images,
    annotations=annotations,
    images_path=train_img_path
)


print("Images shape:", X_train.shape)
print("Masks shape:", Y_train.shape)
# Out:
# Images shape: (1000, 256, 256, 1)
# Masks shape: (1000, 256, 256, 1)

# %%
val_images = val_json['images']
val_annotations = val_json['annotations']
X_val, Y_val = create_dataset(
    images=val_images,
    annotations=val_annotations,
    images_path=val_img_path
)
print("X_val:", X_val.shape)
print("Y_val:", Y_val.shape)
# Out:
# X_val: (200, 256, 256, 1)
# Y_val: (200, 256, 256, 1)

# %% [markdown]
# # 3. Training Model - UNet

# %% [markdown]
# Source of model: https://unicloud.kg.ac.rs/index.php/s/R6Nzi7EoxwmLFs6?dir=/Segmentation%20code

# %%
def unet(input_shape=(256,256,1)):
    inputs = layers.Input(input_shape)

    # Contracting path
    c1 = Conv2D(8, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(inputs)
    c1 = Conv2D(8, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
    p1 = MaxPooling2D((2, 2))(c1)
    p1 = Dropout(0.1)(p1)

    c2 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
    c2 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
    p2 = MaxPooling2D((2, 2))(c2)
    p2 = Dropout(0.1)(p2)

    c3 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
    c3 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
    p3 = MaxPooling2D((2, 2))(c3)
    p3 = Dropout(0.2)(p3)

    c4 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p3)
    c4 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)
    p4 = MaxPooling2D((2, 2))(c4)
    p4 = Dropout(0.2)(p4)


    c5 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p4)
    c5 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)
    p5 = MaxPooling2D(pool_size=(2, 2))(c5)
    p5 = Dropout(0.3)(p5)

    # Final Layer
    c6 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p5)
    c6 = Dropout(0.3)(c6)
    c6 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c6)


    # Expanding path

    u7 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c6)
    u7 = concatenate([u7, c5])
    c7 = Dropout(0.3)(u7)
    c7 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c7)
    c7 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c7)


    u8 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c7)
    u8 = concatenate([u8, c4])
    c8 = Dropout(0.3)(u8)
    c8 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c8)
    c8 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c8)


    u9 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c8)
    u9 = concatenate([u9, c3])
    c9 = Dropout(0.2)(u9)
    c9 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c9)
    c9 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c9)


    u10 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(c9)
    u10 = concatenate([u10, c2])
    c10 = Dropout(0.2)(u10)
    c10 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c10)
    c10 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c10)

    u11 = Conv2DTranspose(8, (2, 2), strides=(2, 2), padding='same')(c10)
    u11 = concatenate([u11, c1], axis=3)
    c11 = Dropout(0.1)(u11)
    c11 = Conv2D(8, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c11)
    c11 = Conv2D(8, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c11)

    outputs = Conv2D(1, (1, 1), activation='sigmoid')(c11)

    return models.Model(inputs, outputs)

# %% [markdown]
# Source code: https://notebook.community/cshallue/models/samples/outreach/blogs/segmentation_blogpost/image_segmentation

# %%
def dice_loss(y_true, y_pred, smooth=1):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return 1 - (2. * intersection + smooth) / (
        tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth
    )

def bce_dice_loss(y_true, y_pred):
    bce = tf.keras.losses.binary_crossentropy(y_true, y_pred)
    return bce + dice_loss(y_true, y_pred)

# %%
def iou_metric(y_true, y_pred, smooth=1e-6):
    y_pred = tf.cast(y_pred > 0.5, tf.float32)
    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) - intersection
    return (intersection + smooth) / (union + smooth)

# %%
model = unet()
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss=bce_dice_loss,
    metrics=[iou_metric]
)

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 256, 256,  │         80 │ input_layer[0][0] │
# │                     │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 256, 256,  │        584 │ conv2d[0][0]      │
# │                     │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 128, 128,  │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128, 128,  │          0 │ max_pooling2d[0]… │
# │                     │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 128, 128,  │      1,168 │ dropout[0][0]     │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 128, 128,  │      2,320 │ conv2d_2[0][0]    │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 64, 64,    │          0 │ conv2d_3[0][0]    │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 64, 64,    │          0 │ max_pooling2d_1[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 64, 64,    │      4,640 │ dropout_1[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 64, 64,    │      9,248 │ conv2d_4[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 32, 32,    │          0 │ conv2d_5[0][0]    │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 32, 32,    │          0 │ max_pooling2d_2[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 32, 32,    │     18,496 │ dropout_2[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 32, 32,    │     36,928 │ conv2d_6[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 16, 16,    │          0 │ conv2d_7[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 16, 16,    │          0 │ max_pooling2d_3[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 16, 16,    │     73,856 │ dropout_3[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 16, 16,    │    147,584 │ conv2d_8[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_4     │ (None, 8, 8, 128) │          0 │ conv2d_9[0][0]    │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 8, 8, 128) │          0 │ max_pooling2d_4[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 8, 8, 256) │    295,168 │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 8, 8, 256) │          0 │ conv2d_10[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 8, 8, 256) │    590,080 │ dropout_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 16, 16,    │    131,200 │ conv2d_11[0][0]   │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 16, 16,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ conv2d_9[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 16, 16,    │          0 │ concatenate[0][0] │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 16, 16,    │    295,040 │ dropout_6[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 16, 16,    │    147,584 │ conv2d_12[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 32, 32,    │     32,832 │ conv2d_13[0][0]   │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ conv2d_7[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 32, 32,    │          0 │ concatenate_1[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 32, 32,    │     73,792 │ dropout_7[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 32, 32,    │     36,928 │ conv2d_14[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 64, 64,    │      8,224 │ conv2d_15[0][0]   │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 64)               │            │ conv2d_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 64, 64,    │          0 │ concatenate_2[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 64, 64,    │     18,464 │ dropout_8[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 64, 64,    │      9,248 │ conv2d_16[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 128, 128,  │      2,064 │ conv2d_17[0][0]   │
# │ (Conv2DTranspose)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 32)               │            │ conv2d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_9 (Dropout) │ (None, 128, 128,  │          0 │ concatenate_3[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 128, 128,  │      4,624 │ dropout_9[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 128, 128,  │      2,320 │ conv2d_18[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_4  │ (None, 256, 256,  │        520 │ conv2d_19[0][0]   │
# │ (Conv2DTranspose)   │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_4       │ (None, 256, 256,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 16)               │            │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_10          │ (None, 256, 256,  │          0 │ concatenate_4[0]… │
# │ (Dropout)           │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 256, 256,  │      1,160 │ dropout_10[0][0]  │
# │                     │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, 256, 256,  │        584 │ conv2d_20[0][0]   │
# │                     │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 256, 256,  │          9 │ conv2d_21[0][0]   │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,944,745 (7.42 MB)
#  Trainable params: 1,944,745 (7.42 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(
    X_train, Y_train,
    validation_data=(X_val, Y_val),
    verbose=1,
    epochs=60,
    batch_size=8,
    shuffle=True
)
# Out:
# Epoch 1/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 345s 3s/step - iou_metric: 0.0341 - loss: 1.5878 - val_iou_metric: 3.4809e-05 - val_loss: 1.1723
# Epoch 2/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 335s 3s/step - iou_metric: 0.0052 - loss: 1.0563 - val_iou_metric: 0.1048 - val_loss: 0.9986
# Epoch 3/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 333s 3s/step - iou_metric: 0.0674 - loss: 0.9006 - val_iou_metric: 0.1617 - val_loss: 0.7881
# Epoch 4/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 336s 3s/step - iou_metric: 0.1736 - loss: 0.7771 - val_iou_metric: 0.3145 - val_loss: 0.7147
# Epoch 5/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 381s 3s/step - iou_metric: 0.3213 - loss: 0.6880 - val_iou_metric: 0.4652 - val_loss: 0.5375
# Epoch 6/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 336s 3s/step - iou_metric: 0.4375 - loss: 0.5379 - val_iou_metric: 0.4988 - val_loss: 0.4681
# Epoch 7/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 339s 3s/step - iou_metric: 0.4810 - loss: 0.4763 - val_iou_metric: 0.5137 - val_loss: 0.4503
# Epoch 8/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 338s 3s/step - iou_metric: 0.5046 - loss: 0.4467 - val_iou_metric: 0.5312 - val_loss: 0.4273
# Epoch 9/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 374s 3s/step - iou_metric: 0.5282 - loss: 0.4195 - val_iou_metric: 0.5485 - val_loss: 0.4095
# Epoch 10/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 337s 3s/step - iou_metric: 0.5423 - loss: 0.4039 - val_iou_metric: 0.5697 - val_loss: 0.3831
# Epoch 11/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 376s 3s/step - iou_metric: 0.5583 - loss: 0.3845 - val_iou_metric: 0.5796 - val_loss: 0.3694
# Epoch 12/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 387s 3s/step - iou_metric: 0.5606 - loss: 0.3812 - val_iou_metric: 0.5810 - val_loss: 0.3687
# Epoch 13/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 378s 3s/step - iou_metric: 0.5748 - loss: 0.3653 - val_iou_metric: 0.5636 - val_loss: 0.3885
# Epoch 14/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 339s 3s/step - iou_metric: 0.5819 - loss: 0.3589 - val_iou_metric: 0.5881 - val_loss: 0.3597
# Epoch 15/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 379s 3s/step - iou_metric: 0.5836 - loss: 0.3560 - val_iou_metric: 0.5945 - val_loss: 0.3530
# Epoch 16/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 335s 3s/step - iou_metric: 0.5967 - loss: 0.3409 - val_iou_metric: 0.6009 - val_loss: 0.3462
# Epoch 17/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 394s 3s/step - iou_metric: 0.6035 - loss: 0.3359 - val_iou_metric: 0.5932 - val_loss: 0.3546
# Epoch 18/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 364s 3s/step - iou_metric: 0.6072 - loss: 0.3323 - val_iou_metric: 0.6068 - val_loss: 0.3399
# Epoch 19/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 387s 3s/step - iou_metric: 0.6237 - loss: 0.3127 - val_iou_metric: 0.6149 - val_loss: 0.3307
# Epoch 20/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 384s 3s/step - iou_metric: 0.6204 - loss: 0.3179 - val_iou_metric: 0.6218 - val_loss: 0.3236
# Epoch 21/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 378s 3s/step - iou_metric: 0.6242 - loss: 0.3135 - val_iou_metric: 0.6229 - val_loss: 0.3209
# Epoch 22/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 382s 3s/step - iou_metric: 0.6372 - loss: 0.2998 - val_iou_metric: 0.6103 - val_loss: 0.3354
# Epoch 23/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 384s 3s/step - iou_metric: 0.6359 - loss: 0.3015 - val_iou_metric: 0.6301 - val_loss: 0.3121
# Epoch 24/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 378s 3s/step - iou_metric: 0.6388 - loss: 0.2990 - val_iou_metric: 0.6292 - val_loss: 0.3152
# Epoch 25/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 388s 3s/step - iou_metric: 0.6458 - loss: 0.2909 - val_iou_metric: 0.6276 - val_loss: 0.3165
# Epoch 26/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 337s 3s/step - iou_metric: 0.6500 - loss: 0.2871 - val_iou_metric: 0.6283 - val_loss: 0.3160
# Epoch 27/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 377s 3s/step - iou_metric: 0.6452 - loss: 0.2921 - val_iou_metric: 0.6415 - val_loss: 0.3009
# Epoch 28/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 336s 3s/step - iou_metric: 0.6497 - loss: 0.2881 - val_iou_metric: 0.6416 - val_loss: 0.3010
# Epoch 29/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 377s 3s/step - iou_metric: 0.6566 - loss: 0.2807 - val_iou_metric: 0.6271 - val_loss: 0.3188
# Epoch 30/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 338s 3s/step - iou_metric: 0.6584 - loss: 0.2780 - val_iou_metric: 0.6421 - val_loss: 0.2993
# Epoch 31/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 380s 3s/step - iou_metric: 0.6669 - loss: 0.2701 - val_iou_metric: 0.6426 - val_loss: 0.2995
# Epoch 32/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 383s 3s/step - iou_metric: 0.6648 - loss: 0.2736 - val_iou_metric: 0.6489 - val_loss: 0.2939
# Epoch 33/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 331s 3s/step - iou_metric: 0.6733 - loss: 0.2639 - val_iou_metric: 0.6463 - val_loss: 0.2956
# Epoch 34/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 387s 3s/step - iou_metric: 0.6711 - loss: 0.2672 - val_iou_metric: 0.6475 - val_loss: 0.2946
# Epoch 35/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 329s 3s/step - iou_metric: 0.6820 - loss: 0.2548 - val_iou_metric: 0.6470 - val_loss: 0.2961
# Epoch 36/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 332s 3s/step - iou_metric: 0.6802 - loss: 0.2585 - val_iou_metric: 0.6463 - val_loss: 0.2978
# Epoch 37/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 384s 3s/step - iou_metric: 0.6810 - loss: 0.2574 - val_iou_metric: 0.6466 - val_loss: 0.2951
# Epoch 38/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 385s 3s/step - iou_metric: 0.6786 - loss: 0.2595 - val_iou_metric: 0.6518 - val_loss: 0.2911
# Epoch 39/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 337s 3s/step - iou_metric: 0.6920 - loss: 0.2473 - val_iou_metric: 0.6437 - val_loss: 0.2995
# Epoch 40/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 335s 3s/step - iou_metric: 0.6885 - loss: 0.2490 - val_iou_metric: 0.6551 - val_loss: 0.2869
# Epoch 41/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 336s 3s/step - iou_metric: 0.6873 - loss: 0.2498 - val_iou_metric: 0.6512 - val_loss: 0.2918
# Epoch 42/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 378s 3s/step - iou_metric: 0.6939 - loss: 0.2452 - val_iou_metric: 0.6565 - val_loss: 0.2870
# Epoch 43/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 386s 3s/step - iou_metric: 0.6940 - loss: 0.2438 - val_iou_metric: 0.6546 - val_loss: 0.2875
# Epoch 44/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 338s 3s/step - iou_metric: 0.6965 - loss: 0.2412 - val_iou_metric: 0.6550 - val_loss: 0.2879
# Epoch 45/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 341s 3s/step - iou_metric: 0.7054 - loss: 0.2331 - val_iou_metric: 0.6520 - val_loss: 0.2909
# Epoch 46/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 334s 3s/step - iou_metric: 0.7115 - loss: 0.2269 - val_iou_metric: 0.6512 - val_loss: 0.2920
# Epoch 47/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 381s 3s/step - iou_metric: 0.7054 - loss: 0.2341 - val_iou_metric: 0.6540 - val_loss: 0.2896
# Epoch 48/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 380s 3s/step - iou_metric: 0.7069 - loss: 0.2325 - val_iou_metric: 0.6561 - val_loss: 0.2874
# Epoch 49/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 339s 3s/step - iou_metric: 0.7198 - loss: 0.2215 - val_iou_metric: 0.6503 - val_loss: 0.2934
# Epoch 50/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 382s 3s/step - iou_metric: 0.7105 - loss: 0.2284 - val_iou_metric: 0.6558 - val_loss: 0.2865
# Epoch 51/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 381s 3s/step - iou_metric: 0.7143 - loss: 0.2256 - val_iou_metric: 0.6576 - val_loss: 0.2859
# Epoch 52/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 382s 3s/step - iou_metric: 0.7231 - loss: 0.2171 - val_iou_metric: 0.6533 - val_loss: 0.2909
# Epoch 53/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 385s 3s/step - iou_metric: 0.7178 - loss: 0.2218 - val_iou_metric: 0.6603 - val_loss: 0.2834
# Epoch 54/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 339s 3s/step - iou_metric: 0.7242 - loss: 0.2173 - val_iou_metric: 0.6561 - val_loss: 0.2869
# Epoch 55/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 378s 3s/step - iou_metric: 0.7208 - loss: 0.2195 - val_iou_metric: 0.6542 - val_loss: 0.2902
# Epoch 56/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 341s 3s/step - iou_metric: 0.7310 - loss: 0.2100 - val_iou_metric: 0.6597 - val_loss: 0.2843
# Epoch 57/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 341s 3s/step - iou_metric: 0.7244 - loss: 0.2154 - val_iou_metric: 0.6643 - val_loss: 0.2801
# Epoch 58/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 381s 3s/step - iou_metric: 0.7331 - loss: 0.2090 - val_iou_metric: 0.6582 - val_loss: 0.2853
# Epoch 59/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 335s 3s/step - iou_metric: 0.7266 - loss: 0.2140 - val_iou_metric: 0.6615 - val_loss: 0.2808
# Epoch 60/60
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 333s 3s/step - iou_metric: 0.7332 - loss: 0.2077 - val_iou_metric: 0.6632 - val_loss: 0.2798

# %%
model.save("/content/gdrive/MyDrive/EMMBIOME/SERBIA/Biomedical Imaging/Seminar Paper/ARCADE/syntax/unet_3.keras") #hdf5 format

# %%
loaded_model = tf.keras.models.load_model(
    "/content/gdrive/MyDrive/EMMBIOME/SERBIA/Biomedical Imaging/Seminar Paper/ARCADE/syntax/unet_3.keras",
    custom_objects={
        "bce_dice_loss": bce_dice_loss,
        "iou_metric": iou_metric
    }
)

# %%
loaded_model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 256, 256,  │         80 │ input_layer[0][0] │
# │                     │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 256, 256,  │        584 │ conv2d[0][0]      │
# │                     │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 128, 128,  │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128, 128,  │          0 │ max_pooling2d[0]… │
# │                     │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 128, 128,  │      1,168 │ dropout[0][0]     │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 128, 128,  │      2,320 │ conv2d_2[0][0]    │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 64, 64,    │          0 │ conv2d_3[0][0]    │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 64, 64,    │          0 │ max_pooling2d_1[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 64, 64,    │      4,640 │ dropout_1[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 64, 64,    │      9,248 │ conv2d_4[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 32, 32,    │          0 │ conv2d_5[0][0]    │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 32, 32,    │          0 │ max_pooling2d_2[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 32, 32,    │     18,496 │ dropout_2[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 32, 32,    │     36,928 │ conv2d_6[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 16, 16,    │          0 │ conv2d_7[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 16, 16,    │          0 │ max_pooling2d_3[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 16, 16,    │     73,856 │ dropout_3[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 16, 16,    │    147,584 │ conv2d_8[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_4     │ (None, 8, 8, 128) │          0 │ conv2d_9[0][0]    │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 8, 8, 128) │          0 │ max_pooling2d_4[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 8, 8, 256) │    295,168 │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 8, 8, 256) │          0 │ conv2d_10[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 8, 8, 256) │    590,080 │ dropout_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 16, 16,    │    131,200 │ conv2d_11[0][0]   │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 16, 16,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ conv2d_9[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 16, 16,    │          0 │ concatenate[0][0] │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 16, 16,    │    295,040 │ dropout_6[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 16, 16,    │    147,584 │ conv2d_12[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 32, 32,    │     32,832 │ conv2d_13[0][0]   │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ conv2d_7[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 32, 32,    │          0 │ concatenate_1[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 32, 32,    │     73,792 │ dropout_7[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 32, 32,    │     36,928 │ conv2d_14[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 64, 64,    │      8,224 │ conv2d_15[0][0]   │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 64)               │            │ conv2d_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 64, 64,    │          0 │ concatenate_2[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 64, 64,    │     18,464 │ dropout_8[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 64, 64,    │      9,248 │ conv2d_16[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 128, 128,  │      2,064 │ conv2d_17[0][0]   │
# │ (Conv2DTranspose)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 32)               │            │ conv2d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_9 (Dropout) │ (None, 128, 128,  │          0 │ concatenate_3[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 128, 128,  │      4,624 │ dropout_9[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 128, 128,  │      2,320 │ conv2d_18[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_4  │ (None, 256, 256,  │        520 │ conv2d_19[0][0]   │
# │ (Conv2DTranspose)   │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_4       │ (None, 256, 256,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 16)               │            │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_10          │ (None, 256, 256,  │          0 │ concatenate_4[0]… │
# │ (Dropout)           │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 256, 256,  │      1,160 │ dropout_10[0][0]  │
# │                     │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, 256, 256,  │        584 │ conv2d_20[0][0]   │
# │                     │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 256, 256,  │          9 │ conv2d_21[0][0]   │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 5,834,237 (22.26 MB)
#  Trainable params: 1,944,745 (7.42 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 3,889,492 (14.84 MB)

# %%
plt.figure(figsize=(12, 5))

# IoU plot
plt.subplot(1, 2, 1)
plt.plot(history.history['iou_metric'], label='Train IoU')
plt.plot(history.history['val_iou_metric'], label='Val IoU')
plt.title('Model IoU')
plt.xlabel('Epoch')
plt.ylabel('IoU')
plt.legend(loc='lower right')
plt.grid(True)

# Loss plot
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
test_img_path = os.path.join(dataset, "test/images")
test_json_path = os.path.join(dataset, "test/annotations/test.json")
test_json = load_json(test_json_path)

# %%
test_images = test_json['images']
test_annotations = test_json['annotations']
X_test, Y_test = create_dataset(
    images=test_images,
    annotations=test_annotations,
    images_path=test_img_path
)

# %%
print("Test images shape:", X_test.shape)
print("Test masks shape:", Y_test.shape)
# Out:
# Test images shape: (300, 256, 256, 1)
# Test masks shape: (300, 256, 256, 1)

# %%
y_pred=loaded_model.predict(X_test)
y_pred_thresholded = y_pred > 0.5

intersection = np.logical_and(Y_test, y_pred_thresholded)
union = np.logical_or(Y_test, y_pred_thresholded)
iou_score = np.sum(intersection) / np.sum(union)
print("IoU score: ", iou_score)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 27s 3s/step
# IoU score:  0.6100434196736039

# %%
def precision_recall_f1(y_true, y_pred):
    y_true = y_true.flatten()
    y_pred = y_pred.flatten()

    tp = np.sum((y_true == 1) & (y_pred == 1))
    fp = np.sum((y_true == 0) & (y_pred == 1))
    fn = np.sum((y_true == 1) & (y_pred == 0))

    precision = tp / (tp + fp + 1e-6)
    recall = tp / (tp + fn + 1e-6)
    f1 = 2 * precision * recall / (precision + recall + 1e-6)

    return precision, recall, f1

metrics = [precision_recall_f1(Y_test[i], y_pred_thresholded[i])
           for i in range(len(Y_test))]

p, r, f1 = np.mean(metrics, axis=0)

print("Precision: ", p)
print("Recall: ",r)
print("F1-score: ", f1)
# Out:
# Precision: 0.7637
# Recall:    0.7587
# F1-score:  0.7513

# %%
import random
def visualize_random_val_predictions(model, X_val, Y_val, num_samples=5):
    indices = random.sample(range(len(X_val)), num_samples)

    plt.figure(figsize=(12, num_samples * 4))

    for i, idx in enumerate(indices):
        pred = loaded_model.predict(X_val[idx:idx+1])[0]
        pred_binary = (pred > 0.5).astype(np.float32)

        # Input image
        plt.subplot(num_samples, 3, i * 3 + 1)
        plt.title(f"Input Image (idx={idx})")
        plt.imshow(X_val[idx].squeeze(), cmap='gray')
        plt.axis('off')

        # Ground truth mask
        plt.subplot(num_samples, 3, i * 3 + 2)
        plt.title("Ground Truth Mask")
        plt.imshow(Y_val[idx].squeeze(), cmap='gray')
        plt.axis('off')

        # Predicted mask
        plt.subplot(num_samples, 3, i * 3 + 3)
        plt.title("Predicted Mask")
        plt.imshow(pred_binary.squeeze(), cmap='gray')
        plt.axis('off')

    plt.tight_layout()
    plt.show()


visualize_random_val_predictions(loaded_model, X_test, Y_test, num_samples=5)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
