# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount = True)
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # 1. Visualize dataset

# %% [markdown]
# Source: https://www.kaggle.com/code/nirmalgaud/artery-segment-classification-and-stenosis-detect

# %%
import os
import json
import numpy as np
import cv2
import matplotlib.pyplot as plt

import tensorflow as tf
from keras import layers, models
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose, BatchNormalization, Dropout, Lambda

# %%
def load_json(json_path): # mask images were stored as json files, so we need this function to read them
    with open(json_path, 'r') as f: # open in read mode
        data = json.load(f)
    return data

# %%
def create_mask(image_shape, segmentation):
    mask = np.zeros(image_shape, dtype=np.uint8) # create an empty mask filled with zeros that has the same shape as the image
    points = np.array(segmentation, dtype=np.int32).reshape(-1, 2) # convert segmentation points to numpy array and reshape
    cv2.fillPoly(mask, [points], color=255) # fill the polygon defined by the points with white color - the vessel region
    return mask

# %%
def visualize_segmentation(image_path, annotations, categories, image_id, image_index):
    img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    img_color = cv2.cvtColor(img, cv2.COLOR_GRAY2RGB)
    img_annotations = [ann for ann in annotations if ann['image_id'] == image_id]
    mask = np.zeros_like(img, dtype=np.uint8)

    for ann in img_annotations:
        category_id = ann['category_id']
        category_name = next(cat['name'] for cat in categories if cat['id'] == category_id)
        segmentation = ann['segmentation']
        ann_mask = create_mask(img.shape, segmentation)
        mask = np.maximum(mask, ann_mask)
        img_color[ann_mask == 255] = [255, 0, 0]

    plt.figure(figsize=(10, 5))
    plt.subplot(1, 2, 1)
    plt.title(f"Original Image {image_index + 1}")
    plt.imshow(img, cmap='gray')
    plt.axis('off')

    plt.subplot(1, 2, 2)
    plt.title(f"Segmented Image {image_index + 1} (ID: {image_id})")
    plt.imshow(img_color)
    plt.axis('off')

    plt.show()
    return mask

# %%
def main():
    base_path = "/content/gdrive/MyDrive/EMMBIOME/SERBIA/Biomedical Imaging/Seminar Paper/ARCADE/syntax"
    train_images_path = os.path.join(base_path, "train", "images")
    train_json_path = os.path.join(base_path, "train", "annotations", "train.json")

    data = load_json(train_json_path)
    images = data['images']
    annotations = data['annotations']
    categories = data['categories']

    for idx, sample_image in enumerate(images[:3]):
        image_id = sample_image['id']
        image_file = sample_image['file_name']
        image_path = os.path.join(train_images_path, image_file)

        print(f"Processing image: {image_file}")
        visualize_segmentation(image_path, annotations, categories, image_id, idx)

if __name__ == "__main__":
    main()
# Out:
# Processing image: 922.png
# Processing image: 793.png
# Processing image: 782.png

# %% [markdown]
# # 2. Preprocessing images and preparing a dataset

# %%
IMG_HEIGHT = 256
IMG_WIDTH = 256
dataset = "/content/gdrive/MyDrive/EMMBIOME/SERBIA/Biomedical Imaging/Seminar Paper/ARCADE/syntax"
train_img_path = os.path.join(dataset, "train/images")
train_json_path = os.path.join(dataset, "train/annotations/train.json")

val_img_path = os.path.join(dataset, "val/images")
val_json_path = os.path.join(dataset, "val/annotations/val.json")

train_json = load_json(train_json_path)
val_json = load_json(val_json_path)

# %%
from skimage.filters import frangi
def preprocess_image(image_path):
    img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    img = cv2.resize(img, (IMG_WIDTH, IMG_HEIGHT))
    img = img.astype(np.float32) / 255.0 
    img = cv2.bilateralFilter(img, 5, 50, 50) # 5: neighborhood diameter, 50: intensity similarity threshold, 50: spatial distance threshold    
    sigmas = np.arange(1, 4, 1) # scales for Frangi filter to detect vessels of different thicknesses
    vesselness = frangi(img, sigmas=sigmas)
    img = np.maximum(img, vesselness)
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
    img= clahe.apply(img)
    return img[..., np.newaxis] # add channel dimension for U-Net input -> shape: (256, 256, 1)

# %%
def preprocess_mask(image_shape, annotations, image_id):
    mask = np.zeros(image_shape, dtype=np.uint8) # create an empty mask filled with zeros 
    for ann in annotations:
        if ann['image_id'] == image_id:
            segmentation = ann['segmentation'] # get the segmentation points for the current image
            ann_mask = create_mask(image_shape, segmentation) # create a binary mask for the current annotation
            mask = np.maximum(mask, ann_mask) # combine masks from multiple annotations by taking the maximum value at each pixel 
    mask = cv2.resize(mask, (IMG_WIDTH, IMG_HEIGHT)) # resize the mask to match the dimensions 256 x 256
    mask = (mask > 0).astype(np.float32) # convert to binary mask (0 and 1) and float32 type for U-Net training
    mask = np.expand_dims(mask, axis=-1) # add channel dimension for U-Net input -> shape: (256, 256, 1)
    return mask

# %%
def create_dataset(images, annotations, images_path):
    X = []
    Y = []

    for img_info in images:
        image_id = img_info['id']
        image_file = img_info['file_name']
        image_path = os.path.join(images_path, image_file)

        image = preprocess_image(image_path)
        mask = preprocess_mask(
            image_shape=cv2.imread(image_path, cv2.IMREAD_GRAYSCALE).shape,
            annotations=annotations,
            image_id=image_id
        )

        X.append(image)
        Y.append(mask)

    return np.array(X), np.array(Y)

# %%
images = train_json['images']
annotations = train_json['annotations']
X_train, Y_train = create_dataset(
    images=images,
    annotations=annotations,
    images_path=train_img_path
)


print("Images shape:", X_train.shape)
print("Masks shape:", Y_train.shape)
# Out:
# Images shape: (1000, 256, 256, 1)
# Masks shape: (1000, 256, 256, 1)

# %%
val_images = val_json['images']
val_annotations = val_json['annotations']
X_val, Y_val = create_dataset(
    images=val_images,
    annotations=val_annotations,
    images_path=val_img_path
)
print("X_val:", X_val.shape)
print("Y_val:", Y_val.shape)
# Out:
# X_val: (200, 256, 256, 1)
# Y_val: (200, 256, 256, 1)

# %% [markdown]
# # 3. Training Model - UNet

# %% [markdown]
# Source of model: https://unicloud.kg.ac.rs/index.php/s/R6Nzi7EoxwmLFs6?dir=/Segmentation%20code

# %%
def unet(input_shape=(256,256,1)):
    inputs = layers.Input(input_shape)

    # Contracting path
    c1 = Conv2D(8, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(inputs)
    c1 = Conv2D(8, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
    p1 = MaxPooling2D((2, 2))(c1)
    p1 = Dropout(0.3)(p1)

    c2 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
    c2 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
    p2 = MaxPooling2D((2, 2))(c2)
    p2 = Dropout(0.3)(p2)

    c3 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
    c3 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
    p3 = MaxPooling2D((2, 2))(c3)
    p3 = Dropout(0.3)(p3)

    c4 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p3)
    c4 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)
    p4 = MaxPooling2D((2, 2))(c4)
    p4 = Dropout(0.3)(p4)


    c5 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p4)
    c5 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)
    p5 = MaxPooling2D(pool_size=(2, 2))(c5)
    p5 = Dropout(0.3)(p5)

    c6 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p5)
    c6 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c6)
    p6 = MaxPooling2D(pool_size=(2, 2))(c6)
    p6 = Dropout(0.3)(p6)

    # Final Layer
    c7 = Conv2D(512, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p6)
    c7 = Dropout(0.3)(c7)
    c7 = Conv2D(512, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c7)


    # Expanding path
    #512
    u8 = Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(c7)
    u8 = concatenate([u8, c6])
    c8 = Dropout(0.3)(u8)
    c8 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c8)
    c8 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c8)


    #256
    u9 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c8)
    u9 = concatenate([u9, c5])
    c9 = Dropout(0.3)(u9)
    c9 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c9)
    c9 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c9)


    #128
    u10 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c9)
    u10 = concatenate([u10, c4])
    c10 = Dropout(0.3)(u10)
    c10 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c10)
    c10 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c10)


    u11 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c10)
    u11 = concatenate([u11, c3])
    c11 = Dropout(0.3)(u11)
    c11 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c11)
    c11 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c11)


    u12 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(c11)
    u12 = concatenate([u12, c2])
    c12 = Dropout(0.3)(u12)
    c12 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c12)
    c12 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c12)


    u13 = Conv2DTranspose(8, (2, 2), strides=(2, 2), padding='same')(c12)
    u13 = concatenate([u13, c1], axis=3)
    c13 = Dropout(0.3)(u13)
    c13 = Conv2D(8, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c13)
    c13 = Conv2D(8, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c13)

    outputs = Conv2D(1, (1, 1), activation='sigmoid')(c13)

    return models.Model(inputs, outputs)

# %%
model = unet()
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_27 (Conv2D)  │ (None, 256, 256,  │         80 │ input_layer_1[0]… │
# │                     │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_28 (Conv2D)  │ (None, 256, 256,  │        584 │ conv2d_27[0][0]   │
# │                     │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_6     │ (None, 128, 128,  │          0 │ conv2d_28[0][0]   │
# │ (MaxPooling2D)      │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_13          │ (None, 128, 128,  │          0 │ max_pooling2d_6[… │
# │ (Dropout)           │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_29 (Conv2D)  │ (None, 128, 128,  │      1,168 │ dropout_13[0][0]  │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_30 (Conv2D)  │ (None, 128, 128,  │      2,320 │ conv2d_29[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_7     │ (None, 64, 64,    │          0 │ conv2d_30[0][0]   │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_14          │ (None, 64, 64,    │          0 │ max_pooling2d_7[… │
# │ (Dropout)           │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_31 (Conv2D)  │ (None, 64, 64,    │      4,640 │ dropout_14[0][0]  │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_32 (Conv2D)  │ (None, 64, 64,    │      9,248 │ conv2d_31[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_8     │ (None, 32, 32,    │          0 │ conv2d_32[0][0]   │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_15          │ (None, 32, 32,    │          0 │ max_pooling2d_8[… │
# │ (Dropout)           │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_33 (Conv2D)  │ (None, 32, 32,    │     18,496 │ dropout_15[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_34 (Conv2D)  │ (None, 32, 32,    │     36,928 │ conv2d_33[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_9     │ (None, 16, 16,    │          0 │ conv2d_34[0][0]   │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_16          │ (None, 16, 16,    │          0 │ max_pooling2d_9[… │
# │ (Dropout)           │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_35 (Conv2D)  │ (None, 16, 16,    │     73,856 │ dropout_16[0][0]  │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_36 (Conv2D)  │ (None, 16, 16,    │    147,584 │ conv2d_35[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_10    │ (None, 8, 8, 128) │          0 │ conv2d_36[0][0]   │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_17          │ (None, 8, 8, 128) │          0 │ max_pooling2d_10… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_37 (Conv2D)  │ (None, 8, 8, 256) │    295,168 │ dropout_17[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_38 (Conv2D)  │ (None, 8, 8, 256) │    590,080 │ conv2d_37[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_11    │ (None, 4, 4, 256) │          0 │ conv2d_38[0][0]   │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_18          │ (None, 4, 4, 256) │          0 │ max_pooling2d_11… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_39 (Conv2D)  │ (None, 4, 4, 512) │  1,180,160 │ dropout_18[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_19          │ (None, 4, 4, 512) │          0 │ conv2d_39[0][0]   │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_40 (Conv2D)  │ (None, 4, 4, 512) │  2,359,808 │ dropout_19[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_6  │ (None, 8, 8, 256) │    524,544 │ conv2d_40[0][0]   │
# │ (Conv2DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_6       │ (None, 8, 8, 512) │          0 │ conv2d_transpose… │
# │ (Concatenate)       │                   │            │ conv2d_38[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_20          │ (None, 8, 8, 512) │          0 │ concatenate_6[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_41 (Conv2D)  │ (None, 8, 8, 256) │  1,179,904 │ dropout_20[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_42 (Conv2D)  │ (None, 8, 8, 256) │    590,080 │ conv2d_41[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_7  │ (None, 16, 16,    │    131,200 │ conv2d_42[0][0]   │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_7       │ (None, 16, 16,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ conv2d_36[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_21          │ (None, 16, 16,    │          0 │ concatenate_7[0]… │
# │ (Dropout)           │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_43 (Conv2D)  │ (None, 16, 16,    │    295,040 │ dropout_21[0][0]  │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_44 (Conv2D)  │ (None, 16, 16,    │    147,584 │ conv2d_43[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_8  │ (None, 32, 32,    │     32,832 │ conv2d_44[0][0]   │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_8       │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ conv2d_34[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_22          │ (None, 32, 32,    │          0 │ concatenate_8[0]… │
# │ (Dropout)           │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_45 (Conv2D)  │ (None, 32, 32,    │     73,792 │ dropout_22[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_46 (Conv2D)  │ (None, 32, 32,    │     36,928 │ conv2d_45[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_9  │ (None, 64, 64,    │      8,224 │ conv2d_46[0][0]   │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_9       │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 64)               │            │ conv2d_32[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_23          │ (None, 64, 64,    │          0 │ concatenate_9[0]… │
# │ (Dropout)           │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_47 (Conv2D)  │ (None, 64, 64,    │     18,464 │ dropout_23[0][0]  │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_48 (Conv2D)  │ (None, 64, 64,    │      9,248 │ conv2d_47[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_10 │ (None, 128, 128,  │      2,064 │ conv2d_48[0][0]   │
# │ (Conv2DTranspose)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_10      │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 32)               │            │ conv2d_30[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_24          │ (None, 128, 128,  │          0 │ concatenate_10[0… │
# │ (Dropout)           │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_49 (Conv2D)  │ (None, 128, 128,  │      4,624 │ dropout_24[0][0]  │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_50 (Conv2D)  │ (None, 128, 128,  │      2,320 │ conv2d_49[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_11 │ (None, 256, 256,  │        520 │ conv2d_50[0][0]   │
# │ (Conv2DTranspose)   │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_11      │ (None, 256, 256,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 16)               │            │ conv2d_28[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_25          │ (None, 256, 256,  │          0 │ concatenate_11[0… │
# │ (Dropout)           │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_51 (Conv2D)  │ (None, 256, 256,  │      1,160 │ dropout_25[0][0]  │
# │                     │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_52 (Conv2D)  │ (None, 256, 256,  │        584 │ conv2d_51[0][0]   │
# │                     │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_53 (Conv2D)  │ (None, 256, 256,  │          9 │ conv2d_52[0][0]   │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 7,779,241 (29.68 MB)
#  Trainable params: 7,779,241 (29.68 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(
    X_train, Y_train,
    validation_data=(X_val, Y_val),
    verbose=1,
    epochs=50,
    batch_size=16,
)
# Out:
# Epoch 1/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 380s 6s/step - accuracy: 0.2082 - loss: 2.1063 - val_accuracy: 0.9484 - val_loss: 1.2883
# Epoch 2/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 386s 6s/step - accuracy: 0.9236 - loss: 1.1620 - val_accuracy: 0.9568 - val_loss: 1.1666
# Epoch 3/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 372s 6s/step - accuracy: 0.9509 - loss: 1.0684 - val_accuracy: 0.9584 - val_loss: 1.1212
# Epoch 4/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 382s 6s/step - accuracy: 0.9543 - loss: 1.0394 - val_accuracy: 0.9586 - val_loss: 1.0789
# Epoch 5/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 392s 6s/step - accuracy: 0.9545 - loss: 1.0153 - val_accuracy: 0.9586 - val_loss: 1.0833
# Epoch 6/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 361s 6s/step - accuracy: 0.9536 - loss: 0.9757 - val_accuracy: 0.9580 - val_loss: 1.1752
# Epoch 7/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 360s 6s/step - accuracy: 0.9518 - loss: 0.9234 - val_accuracy: 0.9580 - val_loss: 1.1940
# Epoch 8/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 382s 6s/step - accuracy: 0.9542 - loss: 0.8665 - val_accuracy: 0.9573 - val_loss: 1.1223
# Epoch 9/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 365s 6s/step - accuracy: 0.9562 - loss: 0.8148 - val_accuracy: 0.9558 - val_loss: 1.0422
# Epoch 10/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 380s 6s/step - accuracy: 0.9596 - loss: 0.7571 - val_accuracy: 0.9540 - val_loss: 0.9904
# Epoch 11/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 360s 6s/step - accuracy: 0.9628 - loss: 0.7068 - val_accuracy: 0.9525 - val_loss: 0.9401
# Epoch 12/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 385s 6s/step - accuracy: 0.9629 - loss: 0.6765 - val_accuracy: 0.9536 - val_loss: 0.8683
# Epoch 13/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 364s 6s/step - accuracy: 0.9655 - loss: 0.6352 - val_accuracy: 0.9525 - val_loss: 0.8131
# Epoch 14/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 361s 6s/step - accuracy: 0.9667 - loss: 0.6091 - val_accuracy: 0.9565 - val_loss: 0.7304
# Epoch 15/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 365s 6s/step - accuracy: 0.9672 - loss: 0.5870 - val_accuracy: 0.9553 - val_loss: 0.7041
# Epoch 16/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 369s 6s/step - accuracy: 0.9683 - loss: 0.5690 - val_accuracy: 0.9585 - val_loss: 0.6627
# Epoch 17/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 366s 6s/step - accuracy: 0.9699 - loss: 0.5485 - val_accuracy: 0.9587 - val_loss: 0.6425
# Epoch 18/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 390s 6s/step - accuracy: 0.9707 - loss: 0.5287 - val_accuracy: 0.9603 - val_loss: 0.6146
# Epoch 19/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 381s 6s/step - accuracy: 0.9717 - loss: 0.5116 - val_accuracy: 0.9617 - val_loss: 0.5932
# Epoch 20/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 372s 6s/step - accuracy: 0.9718 - loss: 0.5084 - val_accuracy: 0.9657 - val_loss: 0.5567
# Epoch 21/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 376s 6s/step - accuracy: 0.9727 - loss: 0.4979 - val_accuracy: 0.9627 - val_loss: 0.5700
# Epoch 22/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 369s 6s/step - accuracy: 0.9724 - loss: 0.4948 - val_accuracy: 0.9650 - val_loss: 0.5411
# Epoch 23/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 367s 6s/step - accuracy: 0.9734 - loss: 0.4715 - val_accuracy: 0.9686 - val_loss: 0.5048
# Epoch 24/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 380s 6s/step - accuracy: 0.9741 - loss: 0.4663 - val_accuracy: 0.9706 - val_loss: 0.4991
# Epoch 25/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 370s 6s/step - accuracy: 0.9749 - loss: 0.4555 - val_accuracy: 0.9701 - val_loss: 0.5036
# Epoch 26/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 378s 6s/step - accuracy: 0.9763 - loss: 0.4327 - val_accuracy: 0.9704 - val_loss: 0.4821
# Epoch 27/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 381s 6s/step - accuracy: 0.9760 - loss: 0.4329 - val_accuracy: 0.9715 - val_loss: 0.4597
# Epoch 28/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 382s 6s/step - accuracy: 0.9770 - loss: 0.4181 - val_accuracy: 0.9729 - val_loss: 0.4588
# Epoch 29/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 368s 6s/step - accuracy: 0.9773 - loss: 0.4103 - val_accuracy: 0.9748 - val_loss: 0.4325
# Epoch 30/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 372s 6s/step - accuracy: 0.9774 - loss: 0.4091 - val_accuracy: 0.9745 - val_loss: 0.4230
# Epoch 31/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 367s 6s/step - accuracy: 0.9784 - loss: 0.3947 - val_accuracy: 0.9759 - val_loss: 0.4098
# Epoch 32/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 381s 6s/step - accuracy: 0.9785 - loss: 0.3927 - val_accuracy: 0.9767 - val_loss: 0.4070
# Epoch 33/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 362s 6s/step - accuracy: 0.9794 - loss: 0.3792 - val_accuracy: 0.9763 - val_loss: 0.3973
# Epoch 34/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 369s 6s/step - accuracy: 0.9796 - loss: 0.3686 - val_accuracy: 0.9770 - val_loss: 0.3891
# Epoch 35/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 365s 6s/step - accuracy: 0.9796 - loss: 0.3681 - val_accuracy: 0.9763 - val_loss: 0.3941
# Epoch 36/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 380s 6s/step - accuracy: 0.9802 - loss: 0.3622 - val_accuracy: 0.9781 - val_loss: 0.3809
# Epoch 37/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 365s 6s/step - accuracy: 0.9800 - loss: 0.3600 - val_accuracy: 0.9781 - val_loss: 0.3784
# Epoch 38/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 370s 6s/step - accuracy: 0.9807 - loss: 0.3536 - val_accuracy: 0.9781 - val_loss: 0.3779
# Epoch 39/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 377s 6s/step - accuracy: 0.9807 - loss: 0.3541 - val_accuracy: 0.9788 - val_loss: 0.3767
# Epoch 40/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 387s 6s/step - accuracy: 0.9808 - loss: 0.3478 - val_accuracy: 0.9784 - val_loss: 0.3758
# Epoch 41/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 368s 6s/step - accuracy: 0.9810 - loss: 0.3434 - val_accuracy: 0.9792 - val_loss: 0.3598
# Epoch 42/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 383s 6s/step - accuracy: 0.9818 - loss: 0.3313 - val_accuracy: 0.9785 - val_loss: 0.3770
# Epoch 43/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 369s 6s/step - accuracy: 0.9815 - loss: 0.3336 - val_accuracy: 0.9787 - val_loss: 0.3691
# Epoch 44/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 377s 6s/step - accuracy: 0.9816 - loss: 0.3272 - val_accuracy: 0.9794 - val_loss: 0.3658
# Epoch 45/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 386s 6s/step - accuracy: 0.9823 - loss: 0.3203 - val_accuracy: 0.9785 - val_loss: 0.3643
# Epoch 46/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 364s 6s/step - accuracy: 0.9831 - loss: 0.3136 - val_accuracy: 0.9796 - val_loss: 0.3545
# Epoch 47/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 388s 6s/step - accuracy: 0.9828 - loss: 0.3123 - val_accuracy: 0.9791 - val_loss: 0.3598
# Epoch 48/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 374s 6s/step - accuracy: 0.9827 - loss: 0.3139 - val_accuracy: 0.9798 - val_loss: 0.3580
# Epoch 49/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 394s 6s/step - accuracy: 0.9832 - loss: 0.3079 - val_accuracy: 0.9795 - val_loss: 0.3592
# Epoch 50/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 369s 6s/step - accuracy: 0.9833 - loss: 0.3022 - val_accuracy: 0.9794 - val_loss: 0.3612

# %%
model.save("/content/gdrive/MyDrive/EMMBIOME/SERBIA/Biomedical Imaging/Seminar Paper/ARCADE/syntax/unet_2.keras") #hdf5 format
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/serialization_lib.py:390: UserWarning: The object being serialized includes a `lambda`. This is unsafe. In order to reload the object, you will have to pass `safe_mode=False` to the loading function. Please avoid using `lambda` in the future, and use named Python functions instead. This is the `lambda` being serialized:     loss=lambda y_true, y_pred:
#
#   return {key: serialize_keras_object(value) for key, value in obj.items()}

# %%
plt.figure(figsize=(12, 5))

# Accuracy plot
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy', color='blue')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

# Loss plot
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss', color='red')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')

plt.show()

# %%
test_img_path = os.path.join(dataset, "test/images")
test_json_path = os.path.join(dataset, "test/annotations/test.json")
test_json = load_json(test_json_path)

# %%
test_images = test_json['images']
test_annotations = test_json['annotations']
X_test, Y_test = create_dataset(
    images=test_images,
    annotations=test_annotations,
    images_path=test_img_path
)

# %%
y_pred=model.predict(X_test) 
y_pred_thresholded = y_pred > 0.5 

intersection = np.logical_and(Y_test, y_pred_thresholded)
union = np.logical_or(Y_test, y_pred_thresholded)
iou_score = np.sum(intersection) / np.sum(union)
print("IoU score: ", iou_score)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step
# IoU score:  0.5337886075181852

# %%
import random
def visualize_random_val_predictions(model, X_val, Y_val, num_samples=5):
    indices = random.sample(range(len(X_val)), num_samples)

    plt.figure(figsize=(12, num_samples * 4))

    for i, idx in enumerate(indices):
        pred = model.predict(X_val[idx:idx+1])[0]
        pred_binary = (pred > 0.5).astype(np.float32)

        # Input image
        plt.subplot(num_samples, 3, i * 3 + 1)
        plt.title(f"Input Image (idx={idx})")
        plt.imshow(X_val[idx].squeeze(), cmap='gray')
        plt.axis('off')

        # Ground truth mask
        plt.subplot(num_samples, 3, i * 3 + 2)
        plt.title("Ground Truth Mask")
        plt.imshow(Y_val[idx].squeeze(), cmap='gray')
        plt.axis('off')

        # Predicted mask
        plt.subplot(num_samples, 3, i * 3 + 3)
        plt.title("Predicted Mask")
        plt.imshow(pred_binary.squeeze(), cmap='gray')
        plt.axis('off')

    plt.tight_layout()
    plt.show()


visualize_random_val_predictions(model, X_test, Y_test, num_samples=5)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step

# %%
def precision_recall_f1(y_true, y_pred):
    y_true = y_true.flatten()
    y_pred = y_pred.flatten()

    tp = np.sum((y_true == 1) & (y_pred == 1)) # true positives: correctly predicted vessel pixels
    fp = np.sum((y_true == 0) & (y_pred == 1)) # false positives: non-vessel pixels incorrectly predicted as vessel
    fn = np.sum((y_true == 1) & (y_pred == 0)) # false negatives: vessel pixels incorrectly predicted as non-vessel

    precision = tp / (tp + fp + 1e-6)
    recall = tp / (tp + fn + 1e-6)
    f1 = 2 * precision * recall / (precision + recall + 1e-6)

    return precision, recall, f1

metrics = [precision_recall_f1(Y_test[i], y_pred_thresholded[i])
           for i in range(len(Y_test))]

p, r, f1 = np.mean(metrics, axis=0)

print("Precision: ", p)
print("Recall: ",r)
print("F1-score: ", f1)
# Out:
# Precision: 0.7218
# Recall:    0.6870
# F1-score:  0.6893
